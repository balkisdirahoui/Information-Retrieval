# %% [markdown]
# <a href="https://colab.research.google.com/github/balkisdirahoui/RI-projet/blob/main/Copie_de_Projet_RI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-terrier

import pyterrier as pt
if not pt.started():
  pt.init(boot_packages=["com.github.terrierteam:terrier-prf:-SNAPSHOT"])
# Out:
# ...
#      |████████████████████████████████| 97 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 34.6 MB/s
# ...
#      |████████████████████████████████| 69 kB 7.0 MB/s
# ...
#      |████████████████████████████████| 255 kB 53.5 MB/s
# ...
#      |████████████████████████████████| 41 kB 252 kB/s
# ...
#      |████████████████████████████████| 294 kB 53.4 MB/s
# ...
#      |████████████████████████████████| 596 kB 51.4 MB/s
# ...
#      |████████████████████████████████| 72 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 45.7 MB/s
# ...
#      |████████████████████████████████| 6.4 MB 42.0 MB/s
# ...
#      |████████████████████████████████| 126 kB 46.0 MB/s
# ...
#      |████████████████████████████████| 291 kB 57.6 MB/s
# ...
#      |████████████████████████████████| 59 kB 6.2 MB/s
# ...
#      |████████████████████████████████| 45 kB 2.7 MB/s
# ...
#   Created wheel for python-terrier: filename=python_terrier-0.8.0-py3-none-any.whl size=103883 sha256=d9f62859fef6788387b90ecfdef1035b997379e004ad78fd8c077450a8a730b4
# ...

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
df_trec =pd.read_csv('/gdrive/MyDrive/SORBONNE/S2/rital/RI/projet/data/variations_trec2019_labeled.csv')

# %%
df_trec
# Out:
#      dataset     q_id                            method transformation_type  \
# 0    msmarco  1037798  WordSwapNeighboringCharacterSwap          mispelling
# 1    msmarco   104861  WordSwapNeighboringCharacterSwap          mispelling
# 2    msmarco  1063750  WordSwapNeighboringCharacterSwap          mispelling
# 3    msmarco  1103812  WordSwapNeighboringCharacterSwap          mispelling
# 4    msmarco  1106007  WordSwapNeighboringCharacterSwap          mispelling
# ..       ...      ...                               ...                 ...
# 424  msmarco   855410                   WordSwapWordNet             synonym
# 425  msmarco    87181                   WordSwapWordNet             synonym
# 426  msmarco    87452                   WordSwapWordNet             synonym
# 427  msmarco   915593                   WordSwapWordNet             synonym
# 428  msmarco   962179                   WordSwapWordNet             synonym
#
# ...

# %%
df_trec["transformation_type"].unique()
# Out:
# array(['mispelling', 'naturality', 'ordering', 'paraphrase', 'synonym'],
#       dtype=object)

# %%
pt.datasets.get_dataset("irds:car/v1.5/train/fold0")
# Out:
# IRDSDataset('car/v1.5/train/fold0')

# %%
#Test  BM25
import os 
pt_index_path = './terrier_trec'

if not os.path.exists(pt_index_path + "/data.properties"):
  # création de l'index. Utilisation de l'itérateur pour parcourir la collection
  indexer = pt.index.IterDictIndexer(pt_index_path)
    # on donne à l'index la fonction pour parcourir l'index avec l'itérateur  get_corpus_iter() 
  # On spécifie les champs à indexer et les meta-données à sauvegarder
  index_ref = indexer.index(cord19.get_corpus_iter(), 
                            fields=('abstract',), 
                            meta=('docno',))
else:
  # dans le cas où l'index existe déjà
  index_ref = pt.IndexRef.of(pt_index_path + "/data.properties")
index = pt.IndexFactory.of(index_ref)
pt.BatchRetrieve(index,wmodel ="BM25")
